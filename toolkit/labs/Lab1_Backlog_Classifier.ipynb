# %% [markdown]
# # Lab 1 – Fine-tune a Backlog Classifier (Stub)
#
# > TODO: Replace placeholders. Designed to run on Colab.

# %%
# Setup
# !pip install scikit-learn pandas numpy

# %%
# TODO: Load sample backlog data
# import pandas as pd
# df = pd.DataFrame({'title': [], 'label': []})
# df.head()

# %%
# TODO: Train baseline model (e.g., LogisticRegression)

# %% [markdown]
# ## Checkpoint
# Explain model output to a peer → satisfies AIPM Domain 3.
