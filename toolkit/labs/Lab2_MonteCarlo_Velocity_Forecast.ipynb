# %% [markdown]
# # Lab 2 – Monte Carlo Velocity Forecast (Stub)

# %%
# Setup
# !pip install numpy matplotlib

# %%
# TODO: Simulate velocities and forecast sprint outcomes

# %%
# TODO: Plot forecast distribution

# %% [markdown]
# ## Checkpoint
# Interpret forecast for planning poker calibration.
