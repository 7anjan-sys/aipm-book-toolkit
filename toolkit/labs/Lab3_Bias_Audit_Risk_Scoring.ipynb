# %% [markdown]
# # Lab 3 – Bias Audit of an AI Risk-Scoring Tool (Stub)

# %%
# Setup
# !pip install pandas numpy

# %%
# TODO: Load synthetic dataset with sensitive attribute

# %%
# TODO: Compute simple fairness metrics (TPR/FPR by group)

# %% [markdown]
# ## Checkpoint
# Document mitigation options and governance notes.
